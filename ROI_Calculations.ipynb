# %%
# property cost 200k

#Step 1: define class/variables/objects
# Step 2: add monthly income using interger input from user/landlord
# Step 3: add monthly expenses using integer input from user/landlord
# step 4 : calculate monthly and yearly cashflow using (income - expenses) and (income-expenses) *12
#step 5 : add property related investments
#step 6 : calculate ROI  via (annual cash flow/total investment) then convert answer to a percentage
# step 7 : ask landlord if ROI is good
# Income ( rental income(2000), laundry(0), storage(0), misc(0)) so total month income is 2000 per month 


# Expenses ( taxes - 150, insurance - 100, utilities - 0, HOA - 0, lawn/snow - 0, vacancy - 100 ,
# repairs - 100, capx - 100, property management - 200, mortgage - 860) add to get total month expenses of 1610


# Cash Flow ( income-expenses) so ( 2000 - 1610) which equls 390

# is 390 a good amount of cash flow

#cash on cash roi/ Roi. What kind of return on your cashflow are you getting

# money you put in (downpayment- 40,000, closing cost - 3000, rehab cost - 7000, misc - 0) add to get 
#total investment = 50000

# take our monthly cashflow of 390 and multiply by 12 to get annual cash flow
# we take our annual cash flow and divide by our totall investment (4680/ 50000) = .0936 or 9.36 %

# so our Roi = 9.36 %

# is a 9.36 roi good?

# %%
# property cost 200k

#Step 1: define variables/objects
# Step 2: add monthly income using interger input from user/landlord
# Step 3: add monthly expenses using integer input from user/landlord
# step 4 : calculate monthly and yearly cashflow using (income - expenses) and (income-expenses) *12
#step 5 : add property related investments
#step 6 : calculate ROI  via (annual cash flow/total investment) then convert answer to a percentage
# step 7 : ask landlord if ROI is good

class ROI:
    
    calc = ROI()
  
    def __init__(self):
        self.total_income = 0
        self.total_expenses = 0
        self.annual_cash_flow = 0
        self.total_investment = 0
       

    # Income ( rental income(2000), laundry(0), storage(0), misc(0)) so total month income is 2000 per month  

    calc.get_income()

    def get_income(self):
        monthly_income = int(input(' How much are you paid in rental income per month?'))
        ask = input('Do you receive any monthly income from laundry, storage, or misc items? y/n ')
        if ask == 'n':
            self.total_income = monthly_income
            
        if ask == 'y':
            other_items = ['laundry',
                           'storage', 
                           'misc']
            other_income = 0
            for item in other_items:
                other_income += int(input(f'How much income do you receive from {items} in dollars? '))
            self.total_income = monthly_income + other_income
        print(f'Your total monthly income is ${self.total_income} ')
        
# Expenses ( taxes - 150, insurance - 100, utilities - 0, HOA - 0, lawn/snow - 0, vacancy - 100 ,
# repairs - 100, capx - 100, property management - 200, mortgage - 860) add to get total month expenses of 1610

    calc.get_expenses()

    def get_expenses(self):
        print("Let's calculate your monthly expenses for this property. ")
        expenses = [
            'taxes', 'insurance', 'utilities', 'HOA', 
            'lawn/snow', 'vacancy', 'repairs', 
            'capital expenditures', 'property management', 'mortgage'
            ]
        for expense in expenses:
            self.total_expenses += int(input(f'How much do you pay monthly for {expense}: '))
        print(f'Your total monthly expenses are ${self.total_expenses}')
    
# monthly cashflow = (monthly income- monthly expenses) 
#take our monthly cashflow of 390 and multiply by 12 to get annual cash flow of 4680

    calc.cash_flow()

    def cash_flow(self):
        print("Let's find out your cashflow for this property. ")

        total_cash_flow = self.total_income - self.total_expenses
        self.annual_cash_flow = total_cash_flow * 12
        print(f'Your total monthly cash flow is ${total_cash_flow} and your annual cash flow ${self.annual_cash_flow}')

# property cost 200k
# # money you put in (downpayment- 40,000, closing cost - 3000, rehab project - 7000, misc - 0) add to get 
#total investment = 50000

    calc.investments()

    def investments(self):
        print("Let's find out how much you have invested in this property. ")
        investments = ['down payment', 'closing costs', 'rehab project', 'miscellaneous']
        for investment in investments:
            self.total_investment += int(input(f'How much did you invest for {investment}: '))
        print(f'Your total investments are ${self.total_investment} ')
        



# we take our annual cash flow and divide by our totall investment (4680/ 50000) = .0936 or 9.36 %
    calc.cash_roi()
    def cash_roi(self):
        print("Now we can calculate your ROI to help determine if this property is a good investment ")

        self.calculate_cash_flow()
        total_cash_roi = self.annual_cash_flow / self.total_investment
        print(f'Your total cash on cash ROI is {total_cash_roi * 100:.2f}% ')
        print(f'When considering your circumstances is {total_cash_roi * 100:.2f}% a good ROI?')
        

# is 9.36% a good roi? that is determined by diferent circumstances so its hard to say
# Out:
#  How much are you paid in rental income per month?2000
# Do you receive any monthly income from laundry, storage, or misc items? y/n n
# Your total monthly income is $2000
# Let's calculate your monthly expenses for this property.
# How much do you pay monthly for taxes: 100
# How much do you pay monthly for insurance: 100
